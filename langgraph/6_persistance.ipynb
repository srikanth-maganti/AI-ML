# %%
#Persistance in the langraph refers ability to save and restore state of the workflow overtime(intermediate states also)
#if server got crashed at intermediate node ,we can simply start execution from that node as we stored the intermediate state(fault tolerance)
# chat application resume chat
# for every super step there is a checkpoint
#threads in persistance(using thread id for each session)
