# %% [markdown]
# ### *Importing Libraries*

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### *Load Dataset*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Datasets/loan_data.csv')
df=dataset.copy()

# %% [markdown]
# ### *Summarize Dataset*

# %%
df.shape
# Out:
# (614, 6)

# %%
df.head()
# Out:
#   gender married   ch  income  loanamt status
# 0   Male      No  1.0    5849      NaN      Y
# 1   Male     Yes  1.0    4583    128.0      N
# 2   Male     Yes  1.0    3000     66.0      Y
# 3   Male     Yes  1.0    2583    120.0      Y
# 4   Male      No  1.0    6000    141.0      Y

# %%
df.isnull().sum()
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %%
df.dtypes
# Out:
# gender      object
# married     object
# ch         float64
# income       int64
# loanamt    float64
# status      object
# dtype: object

# %% [markdown]
# ## Preprocessing

# %%
cols=['ch','loanamt']
df[cols]=df[cols].fillna(df[cols].mean())

# %%
df.isnull().sum()
# Out:
# gender     13
# married     3
# ch          0
# income      0
# loanamt     0
# status      0
# dtype: int64

# %%
df['married']=df['married'].fillna(df.mode().iloc[0])

# %%
df=df.drop(['gender'],axis=1)

# %%
df.head()
# Out:
#   married   ch  income     loanamt status
# 0      No  1.0    5849  146.412162      Y
# 1     Yes  1.0    4583  128.000000      N
# 2     Yes  1.0    3000   66.000000      Y
# 3     Yes  1.0    2583  120.000000      Y
# 4      No  1.0    6000  141.000000      Y

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#       ch  income     loanamt  married_Yes  status_Y
# 0    1.0    5849  146.412162        False      True
# 1    1.0    4583  128.000000         True     False
# 2    1.0    3000   66.000000         True      True
# 3    1.0    2583  120.000000         True      True
# 4    1.0    6000  141.000000        False      True
# ..   ...     ...         ...          ...       ...
# 609  1.0    2900   71.000000        False      True
# 610  1.0    4106   40.000000         True      True
# 611  1.0    8072  253.000000         True      True
# 612  1.0    7583  187.000000         True      True
# 613  0.0    4583  133.000000        False     False
#
# [614 rows x 5 columns]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
df['income']=scaler.fit_transform(df[['income']])
df['loanamt']=scaler.fit_transform(df[['loanamt']])

# %%
df.head()
# Out:
#     ch    income   loanamt  married_Yes  status_Y
# 0  1.0  0.072991  0.000000        False      True
# 1  1.0 -0.134412 -0.219273         True     False
# 2  1.0 -0.393747 -0.957641         True      True
# 3  1.0 -0.462062 -0.314547         True      True
# 4  1.0  0.097728 -0.064454        False      True

# %% [markdown]
# ### *Segregate Dataset into X(Input/IndependentVariable) & Y(Output/DependentVariable)*

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
x
# Out:
# array([[1.0, 0.07299082285068836, 0.0, False],
#        [1.0, -0.13441195378345122, -0.21927331495275867, True],
#        [1.0, -0.3937473372051281, -0.9576409986248737, True],
#        ...,
#        [1.0, 0.437174371395469, 1.2693712085797315, True],
#        [1.0, 0.35706382023109756, 0.4833669001545767, True],
#        [0.0, -0.13441195378345122, -0.15972753401145906, False]],
#       dtype=object)

# %%
y
# Out:
# array([ True, False,  True,  True,  True,  True,  True, False,  True,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#        False,  True, False,  True, False, False, False,  True,  True,
#         True, False,  True, False, False, False,  True, False,  True,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True, False, False,
#        False,  True,  True, False,  True,  True,  True,  True, False,
#        False, False, False, False,  True,  True, False,  True,  True,
#         True, False,  True, False, False, False, False,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
# ...

# %% [markdown]
# ### *Splitting Dataset into Train & Test*

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# ### *Training*

# %%
from sklearn.svm import SVC
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# ### *Prediction for all Test Data*

# %%
c1=float(input("enter first col"))
c2=float(input("enter income"))
c3=float(input("enter  loan amount"))
c4=int(input("enter married or not"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f66770aac2b0> in <cell line: 1>()
# ----> 1 c1=float(input("enter first col"))
#       2 c2=float(input("enter income"))
#       3 c3=float(input("enter  loan amount"))
#       4 c4=int(input("enter married or not"))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
c2=scaler.transform([[c2]])
c3=scaler.transform([[c3]])

# %%
# prompt: predict using user entered data

new_data = [[c1, c2[0][0], c3[0][0], c4]]
y_pred = svc.predict(new_data)

print("Prediction:", y_pred)

# %%
print(svc.predict(data))

# %%
y_pred=svc.predict(x_test)

# %% [markdown]
# ### *Evaluating Model*

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))

# %%
print(svc.score(x_test,y_test))
